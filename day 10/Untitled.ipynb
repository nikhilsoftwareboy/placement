# %%
import asyncio
import time

async def task(name):
    start = time.time()
    print(f"{name} started at", start)

    await asyncio.sleep(3)

    end = time.time()
    print(f"{name} ended at", end)
    print(f"{name} took {end - start:.2f} seconds\n")


async def main():
    overall_start = time.time()

    await asyncio.gather(
        task("Task 1"),
        task("Task 2")
    )

    overall_end = time.time()
    print("Total time:", overall_end - overall_start)



await main()
# Out:
# Task 1 started at 1770359219.5678473
# Task 2 started at 1770359219.5685663
# Task 1 ended at 1770359222.5816517
# Task 1 took 3.01 seconds
#
# Task 2 ended at 1770359222.5824373
# Task 2 took 3.01 seconds
#
# Total time: 3.0148744583129883

# %%
class Car:
    pass
c1=Car()
c1.brand="BMW"
c1.color="black"

c2=Car()
c2.brand="Audi"
c2.price="1cr"
c2.color="blue"

# %%
print(c1.brand)

print(c2.color)
# Out:
# BMW
# blue

# %%
class Car:
    def bread_():
        print("hello
