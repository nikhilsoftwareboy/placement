# %%
class User:
    def __init__(self,name):
        self._name=name

u=User("Tom")
print(u._name)
u._name="Jeery"
# Out:
# Tom

# %%
print(u._name)
# Out:
# Jeery

# %%
class Account:
    def __init__(self,name):
        self.__name=name
ac1=Account("Bob")

# %%
print(ac1.__name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(ac1.__name)
#
# AttributeError: 'Account' object has no attribute '__name'

# %%
ac1.__name="Dogesh Bhai"

# %%
print(ac1.__dict__)
# Out:
# {'_Account__name': 'Bob', '__name': 'Dogesh Bhai'}

# %%
class Students:
    def __init__(self,name):
        self.name=name
        self.__attendence=attendence

    def mark_present(self):
        self.__attendence +=1
    def mark_absent(self):
        pass
    def get_attendance(self):
        return self.__attendance
    def is_eligible(self):
        return self.__attendance >=75

# %%
class BankAccount:
    def __init__(self,name):
        self.name=name
        self.__balance=0

    def __validate_amount(self,amount):
        return amount>0

    def deposit(self,amount):
        if self.__validate_amount(amount):
            self.__balance += amount
        else:
            print("Deposite amount must be +ve")
    def withdraw(self,amount):
        if amount<=self.__balance:
            self._balance -=amount
        else:
            print("infuficent balance")
    def get_balance(self):
        return self.__balance

# %%
class SecureLocker:
    def __init__(self, pin):
        self.__pin = pin
        self.__is_locked = True 
        
    def __verify_pin(self, pin):
        return self.__pin == pin

    def unlock(self, pin):
        if self.__verify_pin(pin):
            self.__is_locked = False
            print("Locker unlocked")
        else:
            print("Incorrect PIN")

    def lock(self):
        self.__is_locked = True
        print("Locker locked")

    def status(self):
        if self.__is_locked:
            print("Locker is Locked") 
my_locker.status()
# Out:
# Locker is Locked

# %%
my_locker.unlock(9999)
# Out:
# Incorrect PIN

# %%
my_locker.unlock(1234)
# Out:
# Locker unlocked

# %%
class Parent:
    def __init__(self,num):
        self.__num=num
    def get_num(self):
        return self.__num
class child(Parent):
    def __init__(self,val,num):
        self.__val=val
    def get_val(self):
        return self.__val
son=Child(100,10)
print("Parent: Num:",son.get_num())
print("Child: Val:",son.get_val())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       9     def get_val(self):
#      10         return self.__val
# ---> 11 son=Child(100,10)
#      12 print("Parent: Num:",son.get_num())
#      13 print("Child: Val:",son.get_val())
#
# NameError: name 'Child' is not defined
