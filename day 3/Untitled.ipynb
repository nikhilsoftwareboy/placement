# %%
a=input("Enter any input")
print(a.replace("<"," "))
print(a.replace(">"," "))
print(a.replace("/"," "))
# Out:
# Enter any input he > theire < gto/
# he > theire   gto/
# he   theire < gto/
# he > theire < gto
