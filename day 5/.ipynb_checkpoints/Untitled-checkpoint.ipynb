# %%
l1=[1,2,3]
l2=[4,5,6]
l1.extend(l2)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
for x in dir():
    print(x)
# Out:
# In
# Out
# PS1
# REPLHooks
# _
# __
# ___
# __builtin__
# __builtins__
# __doc__
# __loader__
# __name__
# __package__
# __session__
# __spec__
# _dh
# _i
# _i1
# _i10
# _i11
# _i12
# _i13
# _i2
# _i3
# _i4
# _i5
# _i6
# _i7
# _i8
# _i9
# _ih
# _ii
# _iii
# _oh
# exit
# get_ipython
# get_last_command
# is_wsl
# l
# l1
# l2
# l3
# open
# original_ps1
# platform
# quit
# sys
# x

# %%
for x in dir():
    if "_" not in x and "__" not in x:
        print(x)
# Out:
# In
# Out
# PS1
# REPLHooks
# exit
# l
# l1
# l2
# l3
# open
# platform
# quit
# sys
# x

# %%
donation=[100,200,500,600,200,300,200,100]
a=donation.count(200)
print(a)
# Out:
# 3

# %%
a=[3,5,73,2,5,7,4,35,7,54,4,2]
a.sort()
print(a)
# Out:
# [2, 2, 3, 4, 4, 5, 5, 7, 7, 35, 54, 73]

# %%
a=[3,5,73,2,5,7,4,35,7,54,4,2]
a.sort(reverse=True)
print(a)
# Out:
# [73, 54, 35, 7, 7, 5, 5, 4, 4, 3, 2, 2]

# %%
list=dir()
list.sort(reverse=True)
print(list)
# Out:
# ['sys', 'quit', 'platform', 'original_ps1', 'open', 'list', 'is_wsl', 'get_last_command', 'get_ipython', 'exit', '_oh', '_iii', '_ii', '_ih', '_i4', '_i3', '_i2', '_i1', '_i', '_dh', '__spec__', '__session__', '__package__', '__name__', '__loader__', '__doc__', '__builtins__', '__builtin__', '___', '__', '_', 'REPLHooks', 'PS1', 'Out', 'In']

# %%
list=[1,4,55,3,2,23,4,55,3,22,4,67,8,6,4]
print(len(list))
# Out:
# 15

# %%
a=set(dir())
print(a)
# Out:
# {'_i', '_ii', '_oh', '_i1', '__', 'quit', 'platform', 'original_ps1', 'Out', '___', 'exit', '__session__', 'sys', '__loader__', '_iii', '__package__', '__doc__', 'is_wsl', 'get_ipython', '_dh', 'get_last_command', '__builtin__', '__spec__', '__builtins__', 'PS1', 'In', '_', 'open', 'REPLHooks', '__name__', '_ih'}

# %%
a=input("Enter Password: ")
if("admin@123" in a):
    print("Logged In")
else:
    print("Error")
# Out:
# Enter Password:  admin@123
# Loged In
